# %% [markdown]
# # App Profile Recommendation for Google Play and App Store

# %% [markdown]
# The aim of this project is to find out what apps are most profitable for Google Play and the App Store.
#
# This pseudo company only builds apps that are free to download and install, and the main source of revenue comes from in-app ads. This means that revenue is greatly influenced by the number of users.
#
# The goal is to analyze the data, help the team of developers understand what apps attract more users and make data-driven decisions.
#
# Documentation for datas source:
# https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/home

# %%
from csv import reader
#The IOS App Store dataset
open_file_Apple = open('AppleStore.csv')
read_file_Apple = reader(open_file_Apple)
ios = list(read_file_Apple)

#The Android Google Store dataset
open_file_Google = open('googleplaystore.csv')
read_file_Google = reader(open_file_Google)
android = list(read_file_Google)

# %%
#Column Headers
ios_header = ios[0]
android_header = android[0]
# Row of IOS and Android without the header row.
ios = ios[1:]
android = android[1:]

def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))
        
explore_data(ios,0,3,True)
explore_data(android,0,3,True)

# iOS_Dataset:
# ---------------
# Number of Rows = 7196
# Number of Columns 16
# ______________________

# Android_Dataset:
# ----------------
# Number of Rows = 10841
# Number of Columns = 13
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 7197
# Number of columns: 16
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %%
# Print headers of columns. 
print(ios_header)
print(android_header)

# Columns that could help us with our analysis:

#For iOS - 'track_name', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user rating', and 'prime_genre'
#For Android = 'App', Category','Rating', 'Reviews', 'Installs','Price','Genre'
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %% [markdown]
# # Data Cleaning
#    _______________________

# %%
# There is an issue with one of the rows not having the right amount of information. 
#This row needs to be deleted.
#To determine the proble row:

print(len(android_header))
for row in android:
    header_length = len(android_header)
    row_length = len(row)
    if row_length != header_length:
        print(row)
        print(android.index(row))


print(android[0])  
print('\n')
print(android[10472])
print('\n')
print(android[10473])
# Comparing the header to row 10472(determined from above code not having the right length of row data),
#and row 10473 (has the right amount of row data)
# Row 10472 has to be deleted 

#del andriod[10472] # Don't run this more than once   
# Row 10472 has been deleted
# Out:
# 13
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
# 10472
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
#
# ['osmino Wi-Fi: free WiFi', 'TOOLS', '4.2', '134203', '4.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Tools', 'August 7, 2018', '6.06.14', '4.4 and up']

# %%
print(len(android))
# The number of rows for Android has gone from 10842 tro 1041 rows.
for row in ios:
    iheader_length = len(ios_header)
    irow_length = len(row)
    if irow_length != iheader_length:
        print(ios.index(row))
    else:
        print('Row data length equals Header lenght', row[1])
# Checked the number of row data in comparison to the column header. All rows have the correct number of row dataset.
# Out:
# 10841
# Row data length equals Header lenght Facebook
# Row data length equals Header lenght Instagram
# Row data length equals Header lenght Clash of Clans
# Row data length equals Header lenght Temple Run
# Row data length equals Header lenght Pandora - Music & Radio
# Row data length equals Header lenght Pinterest
# Row data length equals Header lenght Bible
# Row data length equals Header lenght Candy Crush Saga
# Row data length equals Header lenght Spotify Music
# Row data length equals Header lenght Angry Birds
# Row data length equals Header lenght Subway Surfers
# Row data length equals Header lenght Fruit Ninja Classic
# Row data length equals Header lenght Solitaire
# Row data length equals Header lenght CSR Racing
# Row data length equals Header lenght Crossy Road - Endless Arcade Hopper
# Row data length equals Header lenght Injustice: Gods Among Us
# Row data length equals Header lenght Hay Day
# Row data length equals Header lenght Clear Vision (17+)
# Row data length equals Header lenght Minecraft: Pocket Edition
# Row data length equals Header lenght PAC-MAN
# Row data length equals Header lenght Calorie Counter & Diet Tracker by MyFitnessPal
# Row data length equals Header lenght DragonVale
# Row data length equals Header lenght The Weather Channel: Forecast, Radar & Alerts
# Row data length equals Header lenght Head Soccer
# Row data length equals Header lenght Google – Search made just for mobile
# Row data length equals Header lenght Despicable Me: Minion Rush
# Row data length equals Header lenght The Sims™ FreePlay
# Row data length equals Header lenght Google Earth
# Row data length equals Header lenght Plants vs. Zombies
# Row data length equals Header lenght Sonic Dash
# Row data length equals Header lenght Groupon - Deals, Coupons & Discount Shopping App
# Row data length equals Header lenght 8 Ball Pool™
# Row data length equals Header lenght Tiny Tower - Free City Building
# Row data length equals Header lenght Jetpack Joyride
# Row data length equals Header lenght Bike Race - Top Motorcycle Racing Games
# Row data length equals Header lenght Shazam - Discover music, artists, videos & lyrics
# Row data length equals Header lenght Kim Kardashian: Hollywood
# Row data length equals Header lenght Doodle Jump
# Row data length equals Header lenght Trivia Crack
# Row data length equals Header lenght WordBrain
# Row data length equals Header lenght Sniper 3D Assassin: Shoot to Kill Gun Game
# Row data length equals Header lenght Flow Free
# Row data length equals Header lenght Lose It! – Weight Loss Program and Calorie Counter
# Row data length equals Header lenght Skype for iPhone
# Row data length equals Header lenght Geometry Dash Lite
# Row data length equals Header lenght Draw Something
# Row data length equals Header lenght ▻Sudoku
# Row data length equals Header lenght Twitter
# Row data length equals Header lenght Messenger
# Row data length equals Header lenght Waze - GPS Navigation, Maps & Real-time Traffic
# Row data length equals Header lenght Zillow Real Estate - Homes for Sale & for Rent
# Row data length equals Header lenght Tumblr
# Row data length equals Header lenght Fruit Ninja®
# Row data length equals Header lenght Infinity Blade
# Row data length equals Header lenght Snapchat
# Row data length equals Header lenght Netflix
# Row data length equals Header lenght Starbucks
# Row data length equals Header lenght Pixel Gun 3D
# Row data length equals Header lenght Temple Run 2
# Row data length equals Header lenght My Horse
# Row data length equals Header lenght iHeartRadio – Free Music & Radio Stations
# Row data length equals Header lenght Fandango Movies - Times + Tickets
# Row data length equals Header lenght ESPN: Get scores, news, alerts & watch live sports
# Row data length equals Header lenght WhatsApp Messenger
# Row data length equals Header lenght Word Cookies!
# Row data length equals Header lenght YouTube - Watch Videos, Music, and Live Streams
# Row data length equals Header lenght Dragon City Mobile
# Row data length equals Header lenght The Simpsons™: Tapped Out
# Row data length equals Header lenght Plants vs. Zombies™ 2
# Row data length equals Header lenght Clash Royale
# Row data length equals Header lenght Geometry Dash
# Row data length equals Header lenght eBay: Best App to Buy, Sell, Save! Online Shopping
# Row data length equals Header lenght Kik
# Row data length equals Header lenght Domino's Pizza USA
# Row data length equals Header lenght Pokémon GO
# Row data length equals Header lenght CSR Racing 2
# Row data length equals Header lenght Star Wars™: Commander
# Row data length equals Header lenght Kindle – Read eBooks, Magazines & Textbooks
# Row data length equals Header lenght Colorfy: Coloring Book for Adults
# Row data length equals Header lenght Boom Beach
# Row data length equals Header lenght MARVEL Contest of Champions
# Row data length equals Header lenght Chase Mobile℠
# Row data length equals Header lenght Mint: Personal Finance, Budget, Bills & Money
# Row data length equals Header lenght MADDEN NFL Mobile
# Row data length equals Header lenght Yelp - Nearby Restaurants, Shopping & Services
# Row data length equals Header lenght Bejeweled Blitz
# Row data length equals Header lenght Tiny Wings
# Row data length equals Header lenght Can You Escape
# Row data length equals Header lenght Traffic Rush
# Row data length equals Header lenght The Weather Channel App for iPad – best local forecast, radar map, and storm tracking
# Row data length equals Header lenght Dictionary.com Dictionary & Thesaurus
# Row data length equals Header lenght Fallout Shelter
# Row data length equals Header lenght SimCity BuildIt
# Row data length equals Header lenght Real Basketball
# Row data length equals Header lenght Yahoo Fantasy Sports
# Row data length equals Header lenght WeatherBug - Local Weather, Radar, Maps, Alerts
# Row data length equals Header lenght Asphalt 8: Airborne
# Row data length equals Header lenght Magic Jigsaw Puzzles
# Row data length equals Header lenght Farm Heroes Saga
# Row data length equals Header lenght Pocket God
# Row data length equals Header lenght Beer Pong Game
# Row data length equals Header lenght Glow Hockey 2 FREE
# Row data length equals Header lenght Pictoword: Fun 2 Pics Guess What's the Word Trivia
# Row data length equals Header lenght ROBLOX
# Row data length equals Header lenght IMDb Movies & TV - Trailers and Showtimes
# Row data length equals Header lenght Bejeweled Classic
# Row data length equals Header lenght Daily Celebrity Crossword
# Row data length equals Header lenght AdVenture Capitalist
# Row data length equals Header lenght Blackjack by MobilityWare
# Row data length equals Header lenght Call of Duty®: Heroes
# Row data length equals Header lenght Deer Hunter Classic
# Row data length equals Header lenght ooVoo – Free Video Call, Text and Voice
# Row data length equals Header lenght Agar.io
# Row data length equals Header lenght Piano Tiles (Don't Tap The White Tile)
# Row data length equals Header lenght TRUTH or DARE!!! - FREE
# Row data length equals Header lenght Angry Birds Rio
# Row data length equals Header lenght The Secret Society® - Hidden Mystery
# Row data length equals Header lenght TextNow - Unlimited Text + Calls
# Row data length equals Header lenght Real Racing 3
# Row data length equals Header lenght Highway Rider
# Row data length equals Header lenght Viber Messenger – Text & Call
# Row data length equals Header lenght Plants vs. Zombies HD
# Row data length equals Header lenght Duolingo - Learn Spanish, French and more
# Row data length equals Header lenght Evernote - stay organized
# Row data length equals Header lenght Words with Friends – Best Word Game
# Row data length equals Header lenght WatchESPN
# Row data length equals Header lenght Bowmasters - Top Multiplayer Bowman Archery Game
# Row data length equals Header lenght aa
# Row data length equals Header lenght 2048
# Row data length equals Header lenght Episode - Choose Your Story
# Row data length equals Header lenght Google Maps - Navigation & Transit
# Row data length equals Header lenght Infinity Blade II
# Row data length equals Header lenght Dumb Ways to Die
# Row data length equals Header lenght MyRadar NOAA Weather Radar Forecast
# Row data length equals Header lenght Jurassic World™: The Game
# Row data length equals Header lenght The Masters Tournament
# Row data length equals Header lenght GasBuddy
# Row data length equals Header lenght Color Switch
# Row data length equals Header lenght AccuWeather - Weather for Life
# Row data length equals Header lenght The Room
# Row data length equals Header lenght Plague Inc.
# Row data length equals Header lenght Tinder
# Row data length equals Header lenght Wish - Shopping Made Fun
# Row data length equals Header lenght Iron Force
# Row data length equals Header lenght Racing Penguin Free - Top Flying and Diving Game
# Row data length equals Header lenght Two Dots
# Row data length equals Header lenght Jigsaw Puzzle
# Row data length equals Header lenght Yahoo Sports - Teams, Scores, News & Highlights
# Row data length equals Header lenght Summoners War
# Row data length equals Header lenght Weight Watchers
# Row data length equals Header lenght Gmail - email by Google: secure, fast & organized
# Row data length equals Header lenght SoundCloud - Music & Audio
# Row data length equals Header lenght Sniper Shooter: Gun Shooting Games
# Row data length equals Header lenght Candy Crush Soda Saga
# Row data length equals Header lenght Fox News
# Row data length equals Header lenght Magic Piano by Smule
# Row data length equals Header lenght Where's My Water?
# Row data length equals Header lenght shopkick - Shopping Rewards & Discounts
# Row data length equals Header lenght My Singing Monsters
# Row data length equals Header lenght Flashlight Ⓞ
# Row data length equals Header lenght Spider Solitaire Free by MobilityWare
# Row data length equals Header lenght My Verizon
# Row data length equals Header lenght Amazon App: shop, scan, compare, and read reviews
# Row data length equals Header lenght Smash Hit
# Row data length equals Header lenght ▻Solitaire
# Row data length equals Header lenght My Talking Tom
# Row data length equals Header lenght Pic Collage - Picture Editor & Photo Collage Maker
# Row data length equals Header lenght Funimate video editor: add cool effects to videos
# Row data length equals Header lenght iTranslate - Language Translator & Dictionary
# Row data length equals Header lenght Guess My Age  Math Magic
# Row data length equals Header lenght Clumsy Ninja
# Row data length equals Header lenght Tetris® Blitz
# Row data length equals Header lenght Star Wars™: Galaxy of Heroes
# Row data length equals Header lenght Bubble Mania™
# Row data length equals Header lenght Bank of America - Mobile Banking
# Row data length equals Header lenght PayPal - Send and request money safely
# Row data length equals Header lenght Smule Sing!
# Row data length equals Header lenght Mad Libs
# Row data length equals Header lenght Geometry Dash Meltdown
# Row data length equals Header lenght Beat the Boss 2
# Row data length equals Header lenght Village Life: Love, Marriage and Babies
# Row data length equals Header lenght Call of Duty: Black Ops Zombies
# Row data length equals Header lenght MORTAL KOMBAT X
# Row data length equals Header lenght Sky Burger - Build & Match Food Free
# Row data length equals Header lenght Big Fish Casino – Best Vegas Slot Machines & Games
# Row data length equals Header lenght OpenTable - Restaurant Reservations
# Row data length equals Header lenght Yahoo Mail - Keeps You Organized!
# Row data length equals Header lenght CNN: Breaking US & World News, Live Video
# Row data length equals Header lenght Followers - Social Analytics For Instagram
# Row data length equals Header lenght Yahoo Weather
# Row data length equals Header lenght Monster Legends RPG - War, Fight & Heroes Game
# Row data length equals Header lenght TuneIn Radio - MLB NBA Audiobooks Podcasts Music
# Row data length equals Header lenght Fairway Solitaire Blast
# Row data length equals Header lenght Twitch
# Row data length equals Header lenght Allrecipes Dinner Spinner
# Row data length equals Header lenght Angry Birds 2
# Row data length equals Header lenght myAT&T
# Row data length equals Header lenght Hill Climb Racing
# Row data length equals Header lenght Target
# Row data length equals Header lenght Game of War - Fire Age
# Row data length equals Header lenght slither.io
# Row data length equals Header lenght Cooking Fever
# Row data length equals Header lenght Sunday Lawn
# Row data length equals Header lenght Angry Birds Transformers
# Row data length equals Header lenght ⋆Solitaire
# Row data length equals Header lenght Amazon Music
# Row data length equals Header lenght SCRABBLE Premium
# Row data length equals Header lenght musical.ly - your video social network
# Row data length equals Header lenght Audible – audio books, original series & podcasts
# Row data length equals Header lenght Sleep Cycle alarm clock
# Row data length equals Header lenght ZigZag
# Row data length equals Header lenght Family Guy: The Quest for Stuff
# Row data length equals Header lenght Zappos: shop shoes & clothes, fast free shipping
# Row data length equals Header lenght Credit Karma: Free Credit Scores, Reports & Alerts
# Row data length equals Header lenght DoubleDown Casino & Slots  – Vegas Slot Machines!
# Row data length equals Header lenght Action Movie FX
# Row data length equals Header lenght Text Free: Free Texting + Calling + MMS
# Row data length equals Header lenght MLB.com Home Run Derby 17
# Row data length equals Header lenght The Calculator - Free and Easy Calculating!
# Row data length equals Header lenght Shadow Fight 2
# Row data length equals Header lenght Flick Home Run !
# Row data length equals Header lenght Voice Changer Plus
# Row data length equals Header lenght iFunny :)
# Row data length equals Header lenght Terraria
# Row data length equals Header lenght The CW
# Row data length equals Header lenght War Robots
# Row data length equals Header lenght MeetMe - Chat and Meet New People
# Row data length equals Header lenght Lumosity - Brain Training
# Row data length equals Header lenght Angry Birds Space
# Row data length equals Header lenght Photo Collage Maker & Photo Editor - Live Collage
# Row data length equals Header lenght PewDiePie's Tuber Simulator
# Row data length equals Header lenght Fitbit
# Row data length equals Header lenght We Heart It - Fashion, wallpapers, quotes, tattoos
# Row data length equals Header lenght Vine Camera
# Row data length equals Header lenght Angry Birds HD
# Row data length equals Header lenght Walgreens – Pharmacy, Photo, Coupons and Shopping
# Row data length equals Header lenght Google Photos - unlimited photo and video storage
# Row data length equals Header lenght The Moron Test
# Row data length equals Header lenght Super Mario Run
# Row data length equals Header lenght Tap Titans
# Row data length equals Header lenght Scribblenauts Remix
# Row data length equals Header lenght InsTrack for Instagram - Analytics Plus More
# Row data length equals Header lenght Score! Hero
# Row data length equals Header lenght Angry Birds Epic RPG
# Row data length equals Header lenght Color Therapy Adult Coloring Book for Adults
# Row data length equals Header lenght Hungry Shark Evolution
# Row data length equals Header lenght SoundHound Song Search & Music Player
# Row data length equals Header lenght Candy Blast Mania
# Row data length equals Header lenght Godus
# Row data length equals Header lenght DIRECTV
# Row data length equals Header lenght Township
# Row data length equals Header lenght Best Buy
# Row data length equals Header lenght 4 Pics 1 Word
# Row data length equals Header lenght Blackbox - think outside the box
# Row data length equals Header lenght Flipagram
# Row data length equals Header lenght Zombieville USA 2
# Row data length equals Header lenght Egg, Inc.
# Row data length equals Header lenght DEAD TRIGGER
# Row data length equals Header lenght ABC – Watch Live TV & Stream Full Episodes
# Row data length equals Header lenght Block Craft 3D: Building Simulator Game For Free
# Row data length equals Header lenght Trivia Crack (No Ads)
# Row data length equals Header lenght Solitaire by MobilityWare
# Row data length equals Header lenght Daddy Long Legs
# Row data length equals Header lenght Nyan Cat: Lost In Space
# Row data length equals Header lenght Toy Blast
# Row data length equals Header lenght Angry Birds Go!
# Row data length equals Header lenght Angry Birds Seasons HD
# Row data length equals Header lenght Tango - Free Video Call, Voice and Chat
# Row data length equals Header lenght Covet Fashion - The Game for Dresses & Shopping
# Row data length equals Header lenght QuizUp™
# Row data length equals Header lenght Xbox
# Row data length equals Header lenght LinkedIn
# Row data length equals Header lenght TuneIn Radio Pro - MLB Audiobooks Podcasts Music
# Row data length equals Header lenght Bejeweled Classic HD
# Row data length equals Header lenght Walmart: Free 2-Day Shipping,* Easy Store Shopping
# Row data length equals Header lenght Angry Birds Rio HD
# Row data length equals Header lenght Trigger Fist
# Row data length equals Header lenght Slots - Pharaoh's Way
# Row data length equals Header lenght Stack
# Row data length equals Header lenght UNO ™ & Friends
# Row data length equals Header lenght Bloons TD Battles
# Row data length equals Header lenght Reddit Official App: All That's Trending and Viral
# Row data length equals Header lenght Dream League Soccer 2017
# Row data length equals Header lenght Solitaire·
# Row data length equals Header lenght Ace Fishing: Wild Catch
# Row data length equals Header lenght OverDrive – Library eBooks and Audiobooks
# Row data length equals Header lenght MY LITTLE PONY: Magic Princess Quests
# Row data length equals Header lenght LINE: Disney Tsum Tsum
# Row data length equals Header lenght Speedtest by Ookla
# Row data length equals Header lenght ESPN Fantasy Football Baseball Basketball Hockey
# Row data length equals Header lenght MARVEL Spider-Man Unlimited
# Row data length equals Header lenght Google Docs
# Row data length equals Header lenght Call of Duty: Zombies
# Row data length equals Header lenght Criminal Case
# Row data length equals Header lenght Cut the Rope: Experiments
# Row data length equals Header lenght WordBubbles!
# Row data length equals Header lenght USA TODAY
# Row data length equals Header lenght Match™ - #1 Dating App.
# Row data length equals Header lenght Happy Wheels
# Row data length equals Header lenght Countdown‼ (Event Reminders and Timer)
# Row data length equals Header lenght Cascade: Fun Spin and Match Puzzle Game
# Row data length equals Header lenght Flight Pilot Simulator 3D: Flying Game For Free
# Row data length equals Header lenght Bowling King
# Row data length equals Header lenght Redbox
# Row data length equals Header lenght Skype for iPad
# Row data length equals Header lenght CBS Sports App - Sports Scores, News, Stats, Watch
# Row data length equals Header lenght Google Drive - free online storage
# Row data length equals Header lenght Gummy Drop! – A Match 3 Puzzle Game
# Row data length equals Header lenght Phase 10 Pro - Play Your Friends!
# Row data length equals Header lenght Viva™ Slots Las Vegas Classic Casino Games
# Row data length equals Header lenght Logos Quiz -Guess the most famous brands, new fun!
# Row data length equals Header lenght Elevate - Brain Training and Games
# Row data length equals Header lenght Videoshop - Video Editor
# Row data length equals Header lenght FOX Sports Mobile
# Row data length equals Header lenght OfferUp - Buy. Sell. Simple.
# Row data length equals Header lenght Bingo!™
# Row data length equals Header lenght Talking Tom Cat 2 for iPad
# Row data length equals Header lenght TripAdvisor Hotels Flights Restaurants
# Row data length equals Header lenght Hulu: Watch TV Shows & Stream the Latest Movies
# Row data length equals Header lenght Capital One Mobile
# Row data length equals Header lenght WordWhizzle
# Row data length equals Header lenght NBC – Watch Now and Stream Full TV Episodes
# Row data length equals Header lenght My Boo - Virtual Pet with Mini Games for Kids
# Row data length equals Header lenght Google Chrome – The Fast and Secure Web Browser
# Row data length equals Header lenght Racing Rivals
# Row data length equals Header lenght Emoji>
# Row data length equals Header lenght Apple Store
# Row data length equals Header lenght Piano Tiles 2™(Don't Tap The White Tile 2)
# Row data length equals Header lenght Kendall and Kylie
# Row data length equals Header lenght Shop Savvy Barcode Scanner - Price Compare & Deals
# Row data length equals Header lenght My Talking Angela
# Row data length equals Header lenght Alarm Clock HD Free - Digital Alarm Clock Display
# Row data length equals Header lenght The Sims 3
# Row data length equals Header lenght Mixgram - Picture Collage Maker - Pic Photo Editor
# Row data length equals Header lenght 2016 U.S. Open Golf Championship
# Row data length equals Header lenght Dictionary.com Dictionary & Thesaurus for iPad
# Row data length equals Header lenght HB2 PLUS
# Row data length equals Header lenght StickWars
# Row data length equals Header lenght Period Tracker Lite
# Row data length equals Header lenght 1010!
# Row data length equals Header lenght NYTimes Crossword - Daily Word Puzzle Game
# Row data length equals Header lenght Evil Apples: A Filthy Adult Card & Party Game
# Row data length equals Header lenght WGT Golf Game by Topgolf
# Row data length equals Header lenght Smashy Road: Wanted
# Row data length equals Header lenght Cookie Jam
# Row data length equals Header lenght POF - Best Dating App for Conversations
# Row data length equals Header lenght Shutterfly: Prints, Photo Books, Cards Made Easy
# Row data length equals Header lenght Pic Jointer – Photo Collage, Camera Effects Editor
# Row data length equals Header lenght BATTLE BEARS: Zombies!
# Row data length equals Header lenght Frozen Free Fall
# Row data length equals Header lenght PINK Nation
# Row data length equals Header lenght WordWhizzle Search
# Row data length equals Header lenght Dropbox
# Row data length equals Header lenght Timehop
# Row data length equals Header lenght Uber
# Row data length equals Header lenght Weather Underground: Custom Forecast & Local Radar
# Row data length equals Header lenght Sonos Controller
# Row data length equals Header lenght Citi Mobile®
# Row data length equals Header lenght Jelly Jump
# Row data length equals Header lenght ABC News - US & World News + Live Video
# Row data length equals Header lenght Close Up Pics Quiz - Guess the Word Trivia Games
# Row data length equals Header lenght Microsoft Word
# Row data length equals Header lenght Castle Clash: Brave Squads
# Row data length equals Header lenght Mahjong Journey®
# Row data length equals Header lenght HOOKED - Chat Stories
# Row data length equals Header lenght Calculator Pro for iPad Free - Smart Calculator
# Row data length equals Header lenght DIRECTV App for iPad
# Row data length equals Header lenght Alice in the Mirrors of Albion: Hidden object game
# Row data length equals Header lenght NBC Sports
# Row data length equals Header lenght Lyft
# Row data length equals Header lenght Super Stickman Golf 2
# Row data length equals Header lenght Gangstar Vegas
# Row data length equals Header lenght Seekers Notes: Hidden Mystery
# Row data length equals Header lenght Fit Brains Trainer
# Row data length equals Header lenght NOAA Weather Radar - Weather Forecast & HD Radar
# Row data length equals Header lenght Tricky Test 2™: Genius Brain?
# Row data length equals Header lenght Slayin
# Row data length equals Header lenght Color Pop Effects - Photo Editor & Picture Editing
# Row data length equals Header lenght Modern Combat 5 : The Multiplayer eSports Shooter
# Row data length equals Header lenght Gardenscapes - New Acres
# Row data length equals Header lenght Ski Safari
# Row data length equals Header lenght Lane Splitter
# Row data length equals Header lenght Ibotta: Cash Back App, Grocery Coupons & Shopping
# Row data length equals Header lenght Wooden Block Puzzle - Wood jigsaw fit 1010 matrix
# Row data length equals Header lenght Find My Family, Friends & iPhone - Life360 Locator
# Row data length equals Header lenght CSR Classics
# Row data length equals Header lenght NBA
# Row data length equals Header lenght Amazon Prime Video
# Row data length equals Header lenght Soccer Stars™
# Row data length equals Header lenght Wells Fargo Mobile
# Row data length equals Header lenght Flippy Bottle Extreme! - Marker Flip Tricky 2K16
# Row data length equals Header lenght Hangman.
# Row data length equals Header lenght Bloons TD 5
# Row data length equals Header lenght Billionaire – Business Capitalist Tycoon!
# Row data length equals Header lenght World of Tanks Blitz
# Row data length equals Header lenght Fieldrunners
# Row data length equals Header lenght Super Stickman Golf
# Row data length equals Header lenght Pearl's Peril - Hidden Object Adventures
# Row data length equals Header lenght Real Steel World Robot Boxing
# Row data length equals Header lenght Blitz Brigade: Multiplayer FPS shooter online!
# Row data length equals Header lenght Panda Pop
# Row data length equals Header lenght The Sandbox - Building & Crafting a Pixel World!
# Row data length equals Header lenght Disney Emoji Blitz
# Row data length equals Header lenght NBA LIVE Mobile Basketball
# Row data length equals Header lenght Cat Physics
# Row data length equals Header lenght Photo Grid - photo collage maker & photo editor
# Row data length equals Header lenght YAHTZEE® With Buddies: The Classic Dice Game
# Row data length equals Header lenght Jigsaw Puzzle Collection HD
# Row data length equals Header lenght Whisper - Share, Express, Meet
# Row data length equals Header lenght iSwap Faces LITE
# Row data length equals Header lenght SCRABBLE Premium for iPad
# Row data length equals Header lenght ESPN Tournament Challenge
# Row data length equals Header lenght Microsoft OneNote
# Row data length equals Header lenght Angry Birds Space HD
# Row data length equals Header lenght MOLDIV - Photo Editor, Collage & Beauty Camera
# Row data length equals Header lenght Photo Editor by Aviary
# Row data length equals Header lenght CBS Full Episodes and Live TV
# Row data length equals Header lenght FOX NOW - Watch Full Episodes and Stream Live TV
# Row data length equals Header lenght Fishdom
# Row data length equals Header lenght Indeed Job Search
# Row data length equals Header lenght Disney Crossy Road
# Row data length equals Header lenght Camera Plus: For Macro Photos & Remote Photography
# Row data length equals Header lenght letgo: Buy & Sell Second Hand Stuff
# Row data length equals Header lenght Zombie Frontier 3 – Top Zombie Shooting Game
# Row data length equals Header lenght Lep's World Free - platformer games
# Row data length equals Header lenght Bitmoji - Your Personal Emoji
# Row data length equals Header lenght Infinity Blade III
# Row data length equals Header lenght Best Fiends
# Row data length equals Header lenght 2016 US Open Tennis Championships
# Row data length equals Header lenght Hidden City®: Mystery of Shadows
# Row data length equals Header lenght Flick Kick Field Goal
# Row data length equals Header lenght Calculator‰
# Row data length equals Header lenght The Room Two
# Row data length equals Header lenght Unison League
# Row data length equals Header lenght Hangouts
# Row data length equals Header lenght Gin Rummy Plus - Multiplayer Online Card Game
# Row data length equals Header lenght Hotel Dash Deluxe
# Row data length equals Header lenght CVS Pharmacy
# Row data length equals Header lenght Cartoon Wars
# Row data length equals Header lenght Flashlight ！
# Row data length equals Header lenght Doodle God™
# Row data length equals Header lenght Touchgrind
# Row data length equals Header lenght Angry Birds POP! - Bubble Shooter
# Row data length equals Header lenght Weather Live Free - Weather Forecast & Alerts
# Row data length equals Header lenght Timberman
# Row data length equals Header lenght Yu-Gi-Oh! Duel Links
# Row data length equals Header lenght ClassDojo
# Row data length equals Header lenght Gravity Guy
# Row data length equals Header lenght Multiplayer for Minecraft PE
# Row data length equals Header lenght Sally's Spa
# Row data length equals Header lenght Fishing Kings Free+
# Row data length equals Header lenght Tabs & Chords by Ultimate Guitar - learn and play
# Row data length equals Header lenght Need for Speed™ No Limits
# Row data length equals Header lenght Goat Simulator
# Row data length equals Header lenght Hearthstone
# Row data length equals Header lenght LINE PLAY - Your Avatar World
# Row data length equals Header lenght Photo Lab: Picture Editor, effects & fun face app
# Row data length equals Header lenght WeChat
# Row data length equals Header lenght Victoria’s Secret – The Sexiest Bras & Lingerie
# Row data length equals Header lenght Badoo - Meet New People, Chat, Socialize.
# Row data length equals Header lenght Chase Mobile
# Row data length equals Header lenght Angry Birds Star Wars
# Row data length equals Header lenght Dragon Mania Legends: Dragon Breeding Game
# Row data length equals Header lenght Nike+ Training Club - Workouts & Fitness Plans
# Row data length equals Header lenght Rookie Cam - Photo Editor & Filter Camera
# Row data length equals Header lenght iSlash
# Row data length equals Header lenght Hill Climb Racing 2
# Row data length equals Header lenght Cooking Dash™
# Row data length equals Header lenght Angry Birds Star Wars II
# Row data length equals Header lenght Choices: Stories You Play
# Row data length equals Header lenght White Noise
# Row data length equals Header lenght Egg!
# Row data length equals Header lenght Mr Jump
# Row data length equals Header lenght Zombieville USA
# Row data length equals Header lenght NBC News
# Row data length equals Header lenght Microsoft Outlook - email and calendar
# Row data length equals Header lenght Talking Angela for iPad
# Row data length equals Header lenght I Am T-Pain 2.0
# Row data length equals Header lenght FotoRus -Camera & Photo Editor & Pic Collage Maker
# Row data length equals Header lenght Grand Theft Auto: San Andreas
# Row data length equals Header lenght Jenga
# Row data length equals Header lenght Hotspot Shield Free VPN Proxy & Wi-Fi Privacy
# Row data length equals Header lenght Into the Dead
# Row data length equals Header lenght Candy Crush Jelly Saga
# Row data length equals Header lenght HotelTonight - Great Deals on Last Minute Hotels
# Row data length equals Header lenght Camera+
# Row data length equals Header lenght Solitaire TriPeaks: Classic Card Game
# Row data length equals Header lenght Arrow Ambush
# Row data length equals Header lenght Fun Run 2 - Multiplayer Race
# Row data length equals Header lenght Scanner Pro - PDF document scanner app with OCR
# Row data length equals Header lenght Stick Hero
# Row data length equals Header lenght Crash Bandicoot Nitro Kart 3D
# Row data length equals Header lenght Zombie Tsunami
# Row data length equals Header lenght Hotels & Vacation Rentals by Booking.com
# Row data length equals Header lenght Neko Atsume: Kitty Collector
# Row data length equals Header lenght Recolor - Coloring Book
# Row data length equals Header lenght Talking Ben the Dog for iPad
# Row data length equals Header lenght 100 Balls
# Row data length equals Header lenght Bandsintown Concerts
# Row data length equals Header lenght Lep's World Plus - super best platformer games
# Row data length equals Header lenght Crazy Kitchen
# Row data length equals Header lenght Rolling Sky
# Row data length equals Header lenght Southwest Airlines
# Row data length equals Header lenght Etsy: Shop Handmade, Vintage & Creative Goods
# Row data length equals Header lenght WWE Immortals
# Row data length equals Header lenght World Chef: Restaurant & Cooking Game
# Row data length equals Header lenght Dog Simulator 2015
# Row data length equals Header lenght Legendary Wars
# Row data length equals Header lenght Color Splash
# Row data length equals Header lenght Twist
# Row data length equals Header lenght A Dark Room
# Row data length equals Header lenght Talking Tom Cat for iPad
# Row data length equals Header lenght Blossom Blast Saga - Fun Flower Match & Grow Game
# Row data length equals Header lenght Splashtop Personal - Remote Desktop
# Row data length equals Header lenght Documents 6 - File manager, PDF reader and browser
# Row data length equals Header lenght HuffPost - News, Politics & Entertainment
# Row data length equals Header lenght Trials Frontier
# Row data length equals Header lenght PicsArt Photo Studio: Collage Maker & Pic Editor
# Row data length equals Header lenght Megapolis
# Row data length equals Header lenght Extreme Car Driving Simulator Free
# Row data length equals Header lenght Pop the Lock
# Row data length equals Header lenght Rat On A Skateboard
# Row data length equals Header lenght Quik – GoPro Video Editor to edit clips with music
# Row data length equals Header lenght Followers + for Instagram - Follower Analytics
# Row data length equals Header lenght Karaoke - Sing Karaoke, Unlimited Songs!
# Row data length equals Header lenght YouTube Kids
# Row data length equals Header lenght Block! Hexa Puzzle
# Row data length equals Header lenght Weather Live - Weather Forecast, Radar and Alerts
# Row data length equals Header lenght Yoga Studio
# Row data length equals Header lenght TurboScan™ Pro - document & receipt scanner: scan multiple pages and photos to PDF
# Row data length equals Header lenght Dude Perfect 2
# Row data length equals Header lenght Bloons TD 5 HD
# Row data length equals Header lenght GroupMe
# Row data length equals Header lenght Basketball Stars™
# Row data length equals Header lenght Splice - Video Editor + Movie Maker by GoPro
# Row data length equals Header lenght FINAL FANTASY BRAVE EXVIUS
# Row data length equals Header lenght Doodle Jump FREE - BE WARNED: Insanely addictive
# Row data length equals Header lenght NOAA Radar Pro – Weather Alerts & Forecast
# Row data length equals Header lenght Truecaller - Spam Identification & Block
# Row data length equals Header lenght Browser and File Manager for Documents
# Row data length equals Header lenght Batman: Arkham Origins
# Row data length equals Header lenght Tom's Love Letters
# Row data length equals Header lenght Marco Polo Video Walkie Talkie
# Row data length equals Header lenght Temple Run: Brave
# Row data length equals Header lenght Make It Rain: The Love of Money
# Row data length equals Header lenght Plant Nanny - Water Reminder with Cute Plants
# Row data length equals Header lenght Five Nights at Freddy's
# Row data length equals Header lenght NFL
# Row data length equals Header lenght Cops N Robbers (FPS) - Block Survival Multiplayer
# Row data length equals Header lenght Animal Jam - Play Wild!
# Row data length equals Header lenght Bike Race Pro - Top Motorcycle Racing Game
# Row data length equals Header lenght Google Translate
# Row data length equals Header lenght Trenches
# Row data length equals Header lenght Flashlight for iPhone , iPod and iPad
# Row data length equals Header lenght Driving School 2016
# Row data length equals Header lenght Grand Theft Auto III
# Row data length equals Header lenght MONOPOLY Game
# Row data length equals Header lenght Eden - World Builder
# Row data length equals Header lenght Gilt
# Row data length equals Header lenght Akinator the Genie
# Row data length equals Header lenght My Mixtapez Music
# Row data length equals Header lenght HBO GO
# Row data length equals Header lenght Bad Piggies
# Row data length equals Header lenght Sing Karaoke Songs Unlimited with StarMaker
# Row data length equals Header lenght FreePrints – Photos Delivered
# Row data length equals Header lenght DoorDash - Food Delivery
# Row data length equals Header lenght SMILE Inc.
# Row data length equals Header lenght War Dragons
# Row data length equals Header lenght Tap Sports Baseball 2016
# Row data length equals Header lenght Looney Tunes Dash!
# Row data length equals Header lenght N.O.V.A. 3: Freedom Edition - Near Orbit Vanguard Alliance game
# Row data length equals Header lenght Triller - Music Video & Film Maker
# Row data length equals Header lenght Rayman Jungle Run
# Row data length equals Header lenght Living Earth - Clock & Weather
# Row data length equals Header lenght Ringtones for iPhone & Ringtone Maker
# Row data length equals Header lenght Musi - Unlimited Music For YouTube
# Row data length equals Header lenght Royal Revolt 2 – Defend Your Castle
# Row data length equals Header lenght Disco Zoo
# Row data length equals Header lenght Mobile Strike
# Row data length equals Header lenght Monument Valley
# Row data length equals Header lenght Real Steel
# Row data length equals Header lenght Angry Birds Blast
# Row data length equals Header lenght Turbo Dismount®
# Row data length equals Header lenght Tank War - Geometry Go Shot Color Dot.IO
# Row data length equals Header lenght Flashlight ◎
# Row data length equals Header lenght Google Sheets
# Row data length equals Header lenght 5-0 Radio Pro Police Scanner (Extra Feeds)
# Row data length equals Header lenght Survivors: the Quest®
# Row data length equals Header lenght Faded - Photo Editor
# Row data length equals Header lenght Wizard of OZ: Magic Match
# Row data length equals Header lenght Microsoft Excel
# Row data length equals Header lenght Where's My Perry?
# Row data length equals Header lenght Osmos for iPad
# Row data length equals Header lenght NFL Sunday Ticket
# Row data length equals Header lenght Mercari: Shopping Marketplace to Buy & Sell Stuff
# Row data length equals Header lenght Paper.io
# Row data length equals Header lenght Hungry Shark World
# Row data length equals Header lenght Pigment - Coloring Book for Adults
# Row data length equals Header lenght Miitomo
# Row data length equals Header lenght Clash of Kings - CoK
# Row data length equals Header lenght Assassin's Creed Pirates
# Row data length equals Header lenght The Room Three
# Row data length equals Header lenght Crush the Castle
# Row data length equals Header lenght Vainglory
# Row data length equals Header lenght Square Cash - Send Money for Free
# Row data length equals Header lenght Modern Combat 3: Fallen Nation
# Row data length equals Header lenght Words Crush: Hidden Words!
# Row data length equals Header lenght Angry Birds Friends
# Row data length equals Header lenght My Cafe: Recipes & Stories - World Restaurant Game
# Row data length equals Header lenght SimSimi
# Row data length equals Header lenght Toca Hair Salon 2
# Row data length equals Header lenght Design Home
# Row data length equals Header lenght Grindr - Gay and same sex guys chat, meet and date
# Row data length equals Header lenght 100 PICS Quiz - guess the picture trivia games
# Row data length equals Header lenght Castle Crush: Epic Strategy Game
# Row data length equals Header lenght RainbowKey - Color keyboard themes, fonts & GIF
# Row data length equals Header lenght PAC-MAN 256 - Endless Arcade Maze
# Row data length equals Header lenght Empires & Allies
# Row data length equals Header lenght Crazy Taxi™ City Rush
# Row data length equals Header lenght Storm Radar
# Row data length equals Header lenght Shopular Coupons, Weekly Deals for Target, Walmart
# Row data length equals Header lenght Angry Birds Star Wars HD
# Row data length equals Header lenght Moto X Mayhem
# Row data length equals Header lenght Dungeon Hunter 5 - Multiplayer RPG on iOS
# Row data length equals Header lenght Traffic Racer
# Row data length equals Header lenght Kill Shot Bravo
# Row data length equals Header lenght iGun Pro HD - The Original Gun Application
# Row data length equals Header lenght Airbnb
# Row data length equals Header lenght Where's My Water? 2
# Row data length equals Header lenght Offroad Legends
# Row data length equals Header lenght Robot Unicorn Attack
# Row data length equals Header lenght Sky Guide: View Stars Night or Day
# Row data length equals Header lenght Solitaire Classic Card Game™
# Row data length equals Header lenght Amazing Thief
# Row data length equals Header lenght Vlogger Go Viral - Clicker Game & Vlog Simulator
# Row data length equals Header lenght Inside Out Thought Bubbles
# Row data length equals Header lenght Capital One for iPad
# Row data length equals Header lenght MLB.com At Bat
# Row data length equals Header lenght iFart - The Original Fart Sounds App
# Row data length equals Header lenght Restaurant DASH with Gordon Ramsay
# Row data length equals Header lenght Juice Jam
# Row data length equals Header lenght NBA JAM by EA SPORTS™
# Row data length equals Header lenght Line Rider iRide™
# Row data length equals Header lenght Jelly Splash
# Row data length equals Header lenght Inbox by Gmail
# Row data length equals Header lenght Colorfly : Coloring Book for Adults - Free Games
# Row data length equals Header lenght Robot Unicorn Attack 2
# Row data length equals Header lenght Peggle Classic
# Row data length equals Header lenght Gods of Olympus
# Row data length equals Header lenght RollerCoaster Tycoon® 4 Mobile™
# Row data length equals Header lenght Lifeline...
# Row data length equals Header lenght BADLAND
# Row data length equals Header lenght PAC-MAN Premium
# Row data length equals Header lenght Venmo
# Row data length equals Header lenght Disney Channel – Watch Full Episodes, Movies & TV
# Row data length equals Header lenght MONOPOLY Bingo!
# Row data length equals Header lenght The Walking Dead: No Man's Land
# Row data length equals Header lenght BuzzTube - Video Player for YouTube
# Row data length equals Header lenght Talking Tom & Ben News for iPad
# Row data length equals Header lenght Dungeon Boss
# Row data length equals Header lenght The Championships, Wimbledon 2016 - Tennis Grand Slam
# Row data length equals Header lenght Photon Flash Player for iPad - Flash Video & Games plus Private Web Browser
# Row data length equals Header lenght Tubex - Videos and Music for YouTube
# Row data length equals Header lenght King of Thieves
# Row data length equals Header lenght Roll the Ball™ - slide puzzle
# Row data length equals Header lenght MARVEL Future Fight
# Row data length equals Header lenght Spinny Circle
# Row data length equals Header lenght VS. Racing 2
# Row data length equals Header lenght Wishbone - Compare Anything
# Row data length equals Header lenght Minecraft: Story Mode
# Row data length equals Header lenght happn — Dating app — Find and meet your crush
# Row data length equals Header lenght Paradise Bay
# Row data length equals Header lenght Memrise: learn languages
# Row data length equals Header lenght Dice With Buddies: Fun New Social Dice Game
# Row data length equals Header lenght Peak - Brain Training
# Row data length equals Header lenght Sugar Smash: Book of Life
# Row data length equals Header lenght DraftKings - Daily Fantasy Golf, Baseball, & More
# Row data length equals Header lenght Dubsmash
# Row data length equals Header lenght PicLab Studio - Creative Editing & Graphic Design
# Row data length equals Header lenght Century City
# Row data length equals Header lenght Blek
# Row data length equals Header lenght Grand Theft Auto: Vice City
# Row data length equals Header lenght Adobe Acrobat Reader: View, Create, & Convert PDFs
# Row data length equals Header lenght Talking Ginger for iPad
# Row data length equals Header lenght Hot Shot Slots Games – Vegas Casino Slot Machines
# Row data length equals Header lenght Canvas by Instructure
# Row data length equals Header lenght T-Mobile
# Row data length equals Header lenght USAA Mobile
# Row data length equals Header lenght Survivalcraft
# Row data length equals Header lenght Drive Ahead!
# Row data length equals Header lenght Sonic The Hedgehog
# Row data length equals Header lenght Perfect365 - Custom makeup designs and beauty tips
# Row data length equals Header lenght Heart of Vegas Slots – Casino Slot Machine Games
# Row data length equals Header lenght EA SPORTS™ UFC®
# Row data length equals Header lenght LEGO® Star Wars™:  The Complete Saga
# Row data length equals Header lenght Rat On A Scooter XL
# Row data length equals Header lenght Rodeo Stampede - Sky Zoo Safari
# Row data length equals Header lenght Racing in Car
# Row data length equals Header lenght Bad Piggies HD
# Row data length equals Header lenght Bingo Pop
# Row data length equals Header lenght Fish Tycoon
# Row data length equals Header lenght Virtual Families
# Row data length equals Header lenght The Impossible Quiz!
# Row data length equals Header lenght imo video calls and chat
# Row data length equals Header lenght Sky Gamblers: Storm Raiders
# Row data length equals Header lenght 100! Block Puzzle - Color jigsaw 10x10 board game
# Row data length equals Header lenght SpongeBob Moves In
# Row data length equals Header lenght ABCmouse.com - Early Learning Academy
# Row data length equals Header lenght Dawn of Titans
# Row data length equals Header lenght Talking Tom Gold Run: Fun & Endless Running Game
# Row data length equals Header lenght The Washington Post Classic
# Row data length equals Header lenght RetailMeNot Shopping Deals, Coupons, Savings
# Row data length equals Header lenght Threes!
# Row data length equals Header lenght Freeform – watch live TV & stream full episodes
# Row data length equals Header lenght After School - Funny Anonymous School News
# Row data length equals Header lenght Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran
# Row data length equals Header lenght Letter Soup - Word Game
# Row data length equals Header lenght Sudoku⁺
# Row data length equals Header lenght Ghost Lens+Scary Photo Video Edit&Collage Maker
# Row data length equals Header lenght Carnivores: Dinosaur Hunter Pro
# Row data length equals Header lenght Reckless Getaway
# Row data length equals Header lenght Paper by FiftyThree - Sketch, Diagram, Take Notes
# Row data length equals Header lenght AutoRap by Smule
# Row data length equals Header lenght Animation Throwdown: The Quest for Cards
# Row data length equals Header lenght Five Nights at Freddy's 2
# Row data length equals Header lenght Charades!™
# Row data length equals Header lenght Head Basketball
# Row data length equals Header lenght Poshmark: Buy & Sell Fashion
# Row data length equals Header lenght Kitchen Scramble: Cooking Game
# Row data length equals Header lenght Whole Foods Market
# Row data length equals Header lenght The Amazing Spider-Man
# Row data length equals Header lenght Merged!
# Row data length equals Header lenght UberEATS: Uber for Food Delivery
# Row data length equals Header lenght Zombie Castaways
# Row data length equals Header lenght World Cup Table Tennis™
# Row data length equals Header lenght Quick Reposter - Repost, Regram and Reshare Photos
# Row data length equals Header lenght Runtastic PRO Running, Jogging and Fitness Tracker
# Row data length equals Header lenght Notability
# Row data length equals Header lenght New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition
# Row data length equals Header lenght TaxCaster – Free tax refund calculator
# Row data length equals Header lenght ipsy - Makeup, subscription and beauty tips
# Row data length equals Header lenght Bruh-Button
# Row data length equals Header lenght Willy Wonka Slots: Vegas Casino Slot Machines
# Row data length equals Header lenght MARVEL Avengers Academy
# Row data length equals Header lenght X-War: Clash of Zombies
# Row data length equals Header lenght Disney Magic Kingdoms
# Row data length equals Header lenght Beat the Boss 2 (17+)
# Row data length equals Header lenght I Dig It
# Row data length equals Header lenght Harry Potter: Spells
# Row data length equals Header lenght Flip Diving
# Row data length equals Header lenght Bleacher Report: Sports news, scores, & highlights
# Row data length equals Header lenght Swamp Attack
# Row data length equals Header lenght Shooty Skies - Endless Arcade Flyer
# Row data length equals Header lenght Wallpapers for Me - Themes & Background Images
# Row data length equals Header lenght Warhammer 40,000: Freeblade
# Row data length equals Header lenght Roku
# Row data length equals Header lenght The Silent Age
# Row data length equals Header lenght Merriam-Webster Dictionary
# Row data length equals Header lenght Sworkit - Custom Workouts for Exercise & Fitness
# Row data length equals Header lenght Zombie Catchers
# Row data length equals Header lenght Weibo HD
# Row data length equals Header lenght Camera360 - Selfie Filter Camera, Photo Editor
# Row data length equals Header lenght Univision Deportes: Liga MX, MLS, Fútbol En Vivo
# Row data length equals Header lenght Quizlet: Study Flashcards, Languages & Vocabulary
# Row data length equals Header lenght The Line Zen
# Row data length equals Header lenght Wedding Dash Deluxe
# Row data length equals Header lenght MyScript Calculator - Handwriting calculator
# Row data length equals Header lenght Photomath - Camera Calculator
# ...
# Row data length equals Header lenght Werewolf Special Package
# Row data length equals Header lenght Le bonheur de lire dès 3 ans: learn to read French
# Row data length equals Header lenght 剑倚手游
# Row data length equals Header lenght 電球でテニスしてみた-無料で遊べるミニゲーム
# Row data length equals Header lenght 箱庭シティ鉄道
# Row data length equals Header lenght 平安证券
# Row data length equals Header lenght 謎解き窓ガラスの跡
# Row data length equals Header lenght STUGGOJI
# Row data length equals Header lenght モンスト全国マルチ掲示板 for モンスターストライク！〜タスカンと運極が作れるアプリ〜
# Row data length equals Header lenght 恋する幽霊-カレシ、死んでます。-
# Row data length equals Header lenght 人気の動画まとめてみた。"for YouTube"
# Row data length equals Header lenght キクタン  【Basic】  4000 ～聞いて覚える英単語～(アルク)
# Row data length equals Header lenght Sight Word Games
# Row data length equals Header lenght 謎解き
# Row data length equals Header lenght キクタン 【Super】 12000 ～聞いて覚える英単語～(アルク)
# Row data length equals Header lenght 香哈菜谱-最专业的家常菜谱大全 无广告版
# Row data length equals Header lenght LEAD ZAQ Battle Version
# Row data length equals Header lenght 五目並べ - オンライン対戦搭載！
# Row data length equals Header lenght 王权之战-帝国时代皇室争霸！
# Row data length equals Header lenght The Official DVSA Highway Code
# Row data length equals Header lenght アニメスタジオ物語
# Row data length equals Header lenght [GP]パチスロ デビル メイ クライ クロス(パチスロゲーム)
# Row data length equals Header lenght 冒険ダンジョン村
# Row data length equals Header lenght ほぼ無理ゲー
# Row data length equals Header lenght CUBE 360°　～想像力×知能×反射神経～
# Row data length equals Header lenght Nackt gut aussehen
# Row data length equals Header lenght 勘違い探し（俺のこと・・・）
# Row data length equals Header lenght 凤凰新闻(专业版)-有料的军事新闻、娱乐短视频
# Row data length equals Header lenght スシロー
# Row data length equals Header lenght I see! Math1
# Row data length equals Header lenght 大人のためのかわいいお買い物アプリSUCRESIA(シュクレシア）
# Row data length equals Header lenght 机甲无双－燃即正义 殿堂级战斗手游
# Row data length equals Header lenght 完全犯罪クラブ
# Row data length equals Header lenght こち亀 公式連載アプリ〜こち亀の漫画が読めるアプリ〜
# Row data length equals Header lenght 投资乐VIP-白银黄金贵金属理财投资
# Row data length equals Header lenght 脱出ゲーム KA-MA-KU-RA
# Row data length equals Header lenght 恵方コンパス！【恵方巻を食べる方角がすぐ探せる！】
# Row data length equals Header lenght ヨドバシ
# Row data length equals Header lenght オービスガイド - 新型オービス&ネズミ捕り&検問
# Row data length equals Header lenght 万年历-农历黄历日历天气
# Row data length equals Header lenght The Dance of the Little Water Drops
# Row data length equals Header lenght 777游戏厅-2017超人气掌上游戏厅
# Row data length equals Header lenght 脱出ゲーム Toilet
# Row data length equals Header lenght CITB MAP HS&E test 2016
# Row data length equals Header lenght The Official DVSA Theory Test Kit for Car Drivers
# Row data length equals Header lenght 【負けるが勝ち？】少数派に入れば勝利の7Beget
# Row data length equals Header lenght 脱出ゲーム 心霊学校からの脱出
# Row data length equals Header lenght 指神
# Row data length equals Header lenght ごちうさアラーム　～ココア編～
# Row data length equals Header lenght 彼女の涙が僕を人間にした
# Row data length equals Header lenght Kazehakase fu-ring bank - Tokoname & Nanbu
# Row data length equals Header lenght iSleeping by iSommeil SARL
# Row data length equals Header lenght gogogo
# Row data length equals Header lenght Bowitter for iPhone
# Row data length equals Header lenght 壊して！無限ドリルランド
# Row data length equals Header lenght Anitore EX ～Let's train together！～
# Row data length equals Header lenght 脱出ゲーム Oden
# Row data length equals Header lenght GE's eddie
# Row data length equals Header lenght [GP]アナザーゴッドハーデス-奪われたZEUSver.-(パチスロゲーム)
# Row data length equals Header lenght おやじが跳ぶ
# Row data length equals Header lenght ナイトメアハーレム 女性向け恋愛ゲーム！乙女げーむ
# Row data length equals Header lenght キンニクエスト 筋肉と筋肉と筋肉と呪われし筋肉
# Row data length equals Header lenght Refreshinator - Auto Refresh tool for Ticket sites
# Row data length equals Header lenght モンストマルチ掲示板 〜 The BEST 〜 for モンスターストライク
# Row data length equals Header lenght 战车世纪·经典FC重装机兵归来
# Row data length equals Header lenght HowDidiDo
# Row data length equals Header lenght 四角い頭を丸くする2
# Row data length equals Header lenght Yahoo!防災速報 - 地震や豪雨など災害情報をいち早く通知
# Row data length equals Header lenght 英単語ターゲット1900（5訂版）
# Row data length equals Header lenght 下ヨシ子の「２０１７年　あなたの流生命」
# Row data length equals Header lenght CITB op/spec HS&E test 2016
# Row data length equals Header lenght BarcodeReader「ICONIT」
# Row data length equals Header lenght 性格美男美女診断２
# Row data length equals Header lenght Think in Japanese (Original name:ひとりごと英語)
# Row data length equals Header lenght 【ひっぱりパズル】ズキュ〜〜〜〜ン！
# Row data length equals Header lenght 完全心理プロファイルX
# Row data length equals Header lenght Table Speed
# Row data length equals Header lenght 秒で100億円
# Row data length equals Header lenght 恵方コンパス.
# Row data length equals Header lenght Malodo : Stop au mal de dos
# Row data length equals Header lenght 古墓仙缘-古装恋爱修仙手游
# Row data length equals Header lenght 番茄电玩城
# Row data length equals Header lenght Télécommande pour SFR TV
# Row data length equals Header lenght 大人の脳トレ！ぴたぽん #頭が良くなる #快感ハメコミパズル
# Row data length equals Header lenght Pantheon Warfare: The Chaos of Knights
# Row data length equals Header lenght 笑ったら負け
# Row data length equals Header lenght 「宅建士」過去問題《受験用》
# Row data length equals Header lenght Impots.gouv
# Row data length equals Header lenght 物理パズル:flower（フラワー）
# Row data length equals Header lenght 俺が浮気した時の話、聞く？ 男女の修羅場の話まとめ
# Row data length equals Header lenght 轩辕剑叁外传之天之痕-正版经典仙侠授权
# Row data length equals Header lenght ジーユー
# Row data length equals Header lenght Mon compte pour Free Mobile - Conso & Messagerie
# Row data length equals Header lenght 主播炸金花
# Row data length equals Header lenght 謝罪会見
# Row data length equals Header lenght PetitLyrics
# Row data length equals Header lenght 早くトイレに行きたい
# Row data length equals Header lenght Der Feueralarm
# Row data length equals Header lenght 僕の魔球打てるの？
# Row data length equals Header lenght Emojil - original emoji stamp, decoration camera
# Row data length equals Header lenght アウト～まさか浮気してないよね？～【恋愛不倫探しゲーム】
# Row data length equals Header lenght 애드픽 - 인플루언서가 되어 의미있는 수익을 올리세요!
# Row data length equals Header lenght Spring Festival by BabyBus
# Row data length equals Header lenght CelebrityDiagnosis!
# Row data length equals Header lenght [GP]パチスロ ヱヴァンゲリヲン〜決意の刻〜(パチスロゲーム)
# Row data length equals Header lenght メンタルリープのアプリ：ワンダーウィーク（旧：ワンダーウィークス）
# Row data length equals Header lenght Women's Health: 1500 Kalorien Tag
# Row data length equals Header lenght Clash of Crime Mad City Full
# Row data length equals Header lenght がんばれルルロロ！かさねてブロック
# Row data length equals Header lenght なっとう-人気の納豆育成ゲーム-
# Row data length equals Header lenght 全国マルチ掲示板 for モンスト！〜タスカンと運極ができるアプリ〜
# Row data length equals Header lenght 一筆書きゲーム！無料パズルで脳トレしよう！ by だーぱん
# Row data length equals Header lenght センバツLIVE!2017／第89回選抜高校野球大会公式アプリ
# Row data length equals Header lenght 新・血液型テスト
# Row data length equals Header lenght EggPunch 2 - adventure puzzle game
# Row data length equals Header lenght ジョナサンアプリ　お得なクーポンが使える便利なアプリ
# Row data length equals Header lenght パチスロ黄門ちゃま 喝
# Row data length equals Header lenght Hooty Hoo: Bingo Math
# Row data length equals Header lenght JCnews - Anime & Game Culture
# Row data length equals Header lenght 罪と罰2 -犯人は誰だ!?- 謎解き推理ミステリーサスペンス
# Row data length equals Header lenght AKUMA大戦 -悪魔を合体召喚して魔王を育成する放置ゲーム-
# Row data length equals Header lenght myINK sketch
# Row data length equals Header lenght Periodic Table Chemistry
# Row data length equals Header lenght 心动K歌恋爱季-让我们一起唱歌听歌恋爱吧
# Row data length equals Header lenght さすゆう -さすがは勇者様です-無料放置系お手軽RPG!!
# Row data length equals Header lenght 30秒マン-これクリアできるやついる？-
# Row data length equals Header lenght Kuro no Sekai - It's a Darkness World
# Row data length equals Header lenght 开挂江湖-Q版武侠挂机
# Row data length equals Header lenght 犯人は僕です。－謎解き×探索ノベルゲーム－
# Row data length equals Header lenght js体育资讯
# Row data length equals Header lenght 每日红包
# Row data length equals Header lenght 激Jパチスロ 2027
# Row data length equals Header lenght ビルホッピング
# Row data length equals Header lenght 犯人は僕です。～露天風呂編～
# Row data length equals Header lenght My au
# Row data length equals Header lenght Devil Lord: I shouldn't say that...half of world
# Row data length equals Header lenght Les Anges
# Row data length equals Header lenght 紫马财行理财精英版—安全可靠的投资理财平台
# Row data length equals Header lenght SPI言語 【Study Pro】
# Row data length equals Header lenght みんなの性格検定
# Row data length equals Header lenght テトリマン
# Row data length equals Header lenght iFleeing!
# Row data length equals Header lenght サクッとスッキリ！ラインナンバー！
# Row data length equals Header lenght 僕の妹が死んだ。
# Row data length equals Header lenght ゲスの極み!パリピを探せ!!笑える・ハマる間違い探しゲーム（意外と難問）
# Row data length equals Header lenght 封神榜（洪荒西游英杰传奇）
# Row data length equals Header lenght ピッタリあわせて！脳トレcube
# Row data length equals Header lenght The Pocket Quiz for Pokemon
# Row data length equals Header lenght キモゲーいや、きも毛ー
# Row data length equals Header lenght 出会うカメ
# Row data length equals Header lenght Jishokun-Japanese English Dictionary & Translator
# Row data length equals Header lenght VR MUSEUM
# Row data length equals Header lenght Simple Reversi Online
# Row data length equals Header lenght アイドルの姫　-わたしの青春マテリアル-
# Row data length equals Header lenght Tetminos - Classic Puzzle Game
# Row data length equals Header lenght ゲーム攻略「SGGP」掲示板、SNSな友達出会い
# Row data length equals Header lenght 意味が分かると怖い話-この怖い話の意味分かる？【意味怖】
# Row data length equals Header lenght TOEIC®テストリスニング360問
# Row data length equals Header lenght 诛妖奇遇-3D仙侠恋爱网游年度巨献(浪漫回合)
# Row data length equals Header lenght 泰坦来袭-热血英雄燃爆部落争霸之战
# Row data length equals Header lenght 蒼の彼方のフォーリズム‐ETERNAL SKY-
# Row data length equals Header lenght Verbrechen - echte Polizeifälle aus Deiner Umgebung
# Row data length equals Header lenght MonPetitGazon
# Row data length equals Header lenght Dinosaur Planet
# Row data length equals Header lenght 江湖侠客录－武侠迷必玩单机手游
# Row data length equals Header lenght 巨商传奇
# Row data length equals Header lenght LINE BLOG
# Row data length equals Header lenght CelebrityCamera!
# Row data length equals Header lenght 花札Online
# Row data length equals Header lenght Mundo Lanugo en Navidad – Juegos Navideños
# Row data length equals Header lenght BLW Slow Cook Recipes
# Row data length equals Header lenght ナビタイム ドライブサポーター - NAVITIMEのカーナビアプリ
# Row data length equals Header lenght 琅琊天下 - 原著改编单机武侠角色扮演RPG
# Row data length equals Header lenght Blitzrechnen 2. Klasse - Mathe lernen in der Grundschule mit Klett nach dem offiziellen Lehrplan
# Row data length equals Header lenght FixYou-無料でチャットトークができるSNSマッチングアプリ
# Row data length equals Header lenght 花しらべ 花認識/花検索
# Row data length equals Header lenght 挂机三国-最强挂机游戏
# Row data length equals Header lenght 修仙幻想-经典萌系回合
# Row data length equals Header lenght 逍遥修仙-掌上360度自由视角经典仙侠动作游戏
# Row data length equals Header lenght 天神决-创新仙侠手游
# Row data length equals Header lenght 修仙侠侣-正统中国风仙侠新作
# Row data length equals Header lenght 胜者为王-多人同时在线PK传奇类手机网游！
# Row data length equals Header lenght BrainConnect
# Row data length equals Header lenght ネイティブ1000人と作った英会話～日常英会話編～
# Row data length equals Header lenght Handball EM 2016 Polen
# Row data length equals Header lenght 懸賞ソリティア-懸賞応募でギフト券が稼げるソリティア！-無料懸賞ゲーム
# Row data length equals Header lenght Learn to Speak Italian Fast With MosaLingua
# Row data length equals Header lenght 别动我学姐-校园格斗巅峰之作
# Row data length equals Header lenght Samurai Ninja Puzzle ONIMARU
# Row data length equals Header lenght マイにゃんカフェ
# Row data length equals Header lenght bit-tube - Live Stream Video Chat
# Row data length equals Header lenght うねうね糸
# Row data length equals Header lenght リア充撲滅RUN
# Row data length equals Header lenght 仙侠剑客—大型3D精品ARPG动作神作
# Row data length equals Header lenght 競馬予想 アプリ！馬券予想で収支アップ！競馬 jra 攻略！
# Row data length equals Header lenght Babaji
# Row data length equals Header lenght Calc for Loan
# Row data length equals Header lenght どうして私じゃダメなの？
# Row data length equals Header lenght 出会い系アプリ i-Mail（アイメール）
# Row data length equals Header lenght コンテンツブロッカー280 / 最高の広告ブロック 280blocker
# Row data length equals Header lenght オトナの教科書〜学校じゃ教わらない裏教育クイズ(画像付き)〜
# Row data length equals Header lenght ねこげーむ~ねこ騎士ポチ~簡単で人気の猫ゲーム~基本無料
# Row data length equals Header lenght 大人には解けない問題
# Row data length equals Header lenght 妖萌战姬HD - 日系二次元萌娘卡牌手游
# Row data length equals Header lenght Escape from the Bears of the student council room.
# Row data length equals Header lenght TOEIC®テスト文法640問1
# Row data length equals Header lenght 僕の彼女が成仏するまで
# Row data length equals Header lenght 霸王卧龙传奇（全新转职系统，60种职业供你选择）
# Row data length equals Header lenght When you clear one,million yen CHANCE!!
# Row data length equals Header lenght 謎解き赤い封筒
# Row data length equals Header lenght GETだぜ！じゃねーよｗ for ポケモン
# Row data length equals Header lenght Escape a Halloween Candy Shop
# Row data length equals Header lenght 同城爱约会-单身男女约会神器
# Row data length equals Header lenght 謎解き2016
# Row data length equals Header lenght ImpossibleGO! - You can't clear
# Row data length equals Header lenght Metal Emoji
# Row data length equals Header lenght 机でGOLF
# Row data length equals Header lenght 最佳足球经理(非彩票)
# Row data length equals Header lenght 誰ガ為ノ世界~悲しみと始まりのユグドラシル~
# Row data length equals Header lenght Reversi REAL - Multiplayer Board game
# Row data length equals Header lenght へびでか〜へび刑事純情物語〜【放置ゲーム】
# Row data length equals Header lenght 东方头条（探索版）订阅分享感兴趣的新闻和搞笑视频
# Row data length equals Header lenght Brain IQ Test Adventure
# Row data length equals Header lenght 脳トレ物理パズル【キタコレ！】～IQの限界に挑めるパズルゲーム～ktkr
# Row data length equals Header lenght 金のフレーズ 〜「新TOEIC®TEST 出る単特急 金のフレーズ」収録 〜
# Row data length equals Header lenght 山手線走ってみた。
# Row data length equals Header lenght ABRSM Aural Trainer Grades 1-5
# Row data length equals Header lenght 无敌战舰-经典策略海战巅峰对决
# Row data length equals Header lenght 和我信
# Row data length equals Header lenght ジェスチャー当て
# Row data length equals Header lenght スピードOnline トランプゲーム
# Row data length equals Header lenght まっぷるリンク - 旅行ガイドを丸ごとアプリで持ち歩き
# Row data length equals Header lenght HOOP J for Basketball Scores
# Row data length equals Header lenght SPI非言語 【Study Pro】
# Row data length equals Header lenght こだわりラーメン館
# Row data length equals Header lenght 【意味笑】意味が分かると面白い話-謎解き2ch系推理ゲーム
# Row data length equals Header lenght 疯狂百宝箱
# Row data length equals Header lenght 針の穴
# Row data length equals Header lenght RPG 偽りの物語 / ドット絵ロールプレイングゲーム
# Row data length equals Header lenght 国美在线 – 新人免费领200元优惠券
# Row data length equals Header lenght Tchapper Messenger - Keep it private
# Row data length equals Header lenght 鬼畜三国-红将觉醒
# Row data length equals Header lenght 食べないと死ぬ2
# Row data length equals Header lenght 单读-我们的黄金时代
# Row data length equals Header lenght 脱出ゲーム　ピラミッドからの脱出
# Row data length equals Header lenght 無料で音楽や写真・カメラの裏技アプリ for iPhone7
# Row data length equals Header lenght 自転車ナビ by NAVITIME(ナビタイム) - 自転車のナビができるアプリ
# Row data length equals Header lenght 謎解きロッカーの忘れ物
# Row data length equals Header lenght 大人の納車ゲーム-四角いアタマを丸くする脳トレパズル
# Row data length equals Header lenght ねことダンボール
# Row data length equals Header lenght ２ちゃんねる for iPhone
# Row data length equals Header lenght 喔豆-发现世间美味
# Row data length equals Header lenght 梦幻仙途-经典之余又大搞趣味创新（回合制）
# Row data length equals Header lenght Golden Lotus Slots
# Row data length equals Header lenght 借金あるからギャンブルしてくる
# Row data length equals Header lenght ファッション通販 ZOZOTOWN
# Row data length equals Header lenght マッチング チャット - マッチング&恋人探しチャット
# Row data length equals Header lenght Bestshot: Take Clear Photos Automatically & Easily
# Row data length equals Header lenght Be-be-bears!
# Row data length equals Header lenght 理财咖(管家版)-金融投资理财产品多样的手机理财工具!
# Row data length equals Header lenght 弑仙问情
# Row data length equals Header lenght 口袋理财（标准版）-上市公司报喜鸟投资
# Row data length equals Header lenght Hey Duggee: We Love Animals
# Row data length equals Header lenght 友達 恋人探し であい ちゃっと sns -ギャルとも
# Row data length equals Header lenght 【難問謎解き】ねこ神様はクイズ好き？
# Row data length equals Header lenght 【悲報】鬼ヶ島終了のお知らせ　-ゾンビ桃太郎が3Dすぎて鬼やばいwww-
# Row data length equals Header lenght 中学英文法総復習 パターンで覚える 瞬間英文法
# Row data length equals Header lenght Brain15 − 脳トレ 無料パズル −
# Row data length equals Header lenght Shark Boom - Challenge Friends with your Pet
# Row data length equals Header lenght 【謎解き】ヤミすぎ彼女からのメッセージ
# Row data length equals Header lenght Go!Go!Cat!
# Row data length equals Header lenght Suppin Detective: Expose their true visage!
# Row data length equals Header lenght みんなのお弁当 by クックパッド ~お弁当をレシピ付きで記録・共有~

# %%
# The Google Play dataset has a few duplicate enteries.
# An example of a duplicate entry is:

for app in android:
    name = app[0]
    if name == 'Facebook':
        print(app)
        
# Facebook has two enteries which means it has a duplicate entry.

#Another duplicate entry:

for app in android:
    name = app[0]
    if name == 'Google Ads':
        print(app)
#Google Ads has three entries.

# To find the number of apps with duplicate entries:

unique_entry = []
duplicate_entry = []

for app in android:
    name = app[0]
    if name in unique_entry:
        duplicate_entry.append(name)
    else:
        unique_entry.append(name)
        
print('Number of duplicate apps enteries are:' ,len(duplicate_entry))
# There are 1181 duplicate apps enteries
print('/n')
print('Some apps with duplicate enteries are: ', duplicate_entry[:10])

#Some apps with duplicate enteries are:  
#['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack']
# Out:
# ['Facebook', 'SOCIAL', '4.1', '78158306', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'August 3, 2018', 'Varies with device', 'Varies with device']
# ['Facebook', 'SOCIAL', '4.1', '78128208', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'August 3, 2018', 'Varies with device', 'Varies with device']
# ['Google Ads', 'BUSINESS', '4.3', '29313', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up']
# ['Google Ads', 'BUSINESS', '4.3', '29313', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up']
# ['Google Ads', 'BUSINESS', '4.3', '29331', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up']
# Number of duplicate apps enteries are: 1181
# /n
# Some apps with duplicate enteries are:  ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack']

# %%
# We do not want multiple enteries for each app. To determine which entry for each app to keep
# We have to choose the entry that has the higher number of revie
#For example, Facebook has two enteries:
# Entry1 - ['Facebook', 'SOCIAL', '4.1', '78158306', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'August 3, 2018', 'Varies with device', 'Varies with device']
# Entry2 - ['Facebook', 'SOCIAL', '4.1', '78128208', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'August 3, 2018', 'Varies with device', 'Varies with device']

# Column 4 in the header represents the number of reviews:
print(android_header)
#['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#So we would be keeping 'Entry1' because it has more reviews.
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
